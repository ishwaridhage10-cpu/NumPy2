# %% [markdown]
# <a href="https://colab.research.google.com/github/ishwaridhage10-cpu/NumPy2/blob/main/Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr = np.random.randint(1, 51, 20)

print("Array:")
print(arr)

print("Minimum Value:", np.min(arr))
print("Index of Minimum Value:", np.argmin(arr))

print("Maximum Value:", np.max(arr))
print("Index of Maximum Value:", np.argmax(arr))

print("Sum:", np.sum(arr))
print("Mean:", np.mean(arr))
print("Standard Deviation:", np.std(arr))
# Out:
# Array:
# [ 3 14 41 27 26  6 28 48 21 43 38  9 17 36 11 15  7 42  9  1]
# Minimum Value: 1
# Index of Minimum Value: 19
# Maximum Value: 48
# Index of Maximum Value: 7
# Sum: 442
# Mean: 22.1
# Standard Deviation: 14.642062696218726
